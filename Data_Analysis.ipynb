# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset['Gender'].fillna('Male', inplace=True)
dataset['Married'].fillna('Yes', inplace=True)
dataset['Self_Employed'].fillna('No', inplace=True)
dataset['LoanAmount'].fillna(dataset['LoanAmount'].median(), inplace=True)
dataset['Credit_History'].fillna(2, inplace=True)
dataset['Loan_Amount_Term'].fillna(dataset['Loan_Amount_Term'].mean(), inplace=True)

# %%
dataset=pd.get_dummies(dataset,columns=['Loan_Status'],drop_first=True)

# %%
dataset=dataset.drop('Loan_ID',axis=1)

# %%
dataset.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area  Loan_Status_Y
# 0         Urban              1
# 1         Rural              0
# ...

# %%
dataset=pd.get_dummies(dataset,columns=['Education','Self_Employed','Gender','Married','Property_Area'],drop_first=True)

# %%
dataset.head()
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0             5849                0.0       128.0
# 1          1             4583             1508.0       128.0
# 2          0             3000                0.0        66.0
# 3          0             2583             2358.0       120.0
# 4          0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Loan_Status_Y  Education_Not Graduate  \
# 0             360.0             1.0              1                       0
# 1             360.0             1.0              0                       0
# 2             360.0             1.0              1                       0
# 3             360.0             1.0              1                       1
# 4             360.0             1.0              1                       0
#
#    Self_Employed_Yes  Gender_Male  Married_Yes  Property_Area_Semiurban  \
# ...

# %%
sns.violinplot(data=dataset,x='Dependents',y='Loan_Status_Y')

# %%
sns.catplot(data=dataset,y='Loan_Amount_Term',x='Loan_Status_Y')

# %%
sns.scatterplot(data=dataset,y='LoanAmount',x='Loan_Status_Y')

# %%
sns.catplot(data=dataset,x='Gender_Male',y='Loan_Status_Y',kind="swarm")

# %%
sns.violinplot(data=dataset,x='Gender_Male',y='Loan_Status_Y')

# %%
sns.violinplot(data=dataset,x='Married_Yes',y='Loan_Status_Y')

# %%
sns.catplot(data=dataset,x='Education_Not Graduate',y='Loan_Status_Y',kind="swarm")

# %%
sns.catplot(data=dataset,x='Property_Area_Semiurban',y='Loan_Status_Y')

# %%
sns.violinplot(data=dataset,x='Property_Area_Urban',y='Loan_Status_Y')

# %%
sns.catplot(data=dataset,x='Education_Not Graduate',y='Loan_Status_Y')

# %%
sns.scatterplot(data=dataset,x='CoapplicantIncome',y='Loan_Status_Y')

# %%
sns.scatterplot(data=dataset,x='ApplicantIncome',y='Loan_Status_Y')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
sns.jointplot(data=dataset,x='Gender_Male',y='Married_Yes',kind='hex')

# %%
#df=sns.load_dataset("dataset")
sns.pairplot(dataset);

# %%
sns.distplot(dataset['ApplicantIncome'])

# %%
sns.distplot(dataset['LoanAmount'])

# %%
sns.distplot(dataset['Loan_Amount_Term'])
